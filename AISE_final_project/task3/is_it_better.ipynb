# %%
import numpy as np
from scipy.integrate import solve_ivp
import torch
import torch.nn.functional as F
import torch.nn as nn
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader



def generate_fourier_ic(x, n_modes=None, seed=None):

    """
    Generate random Fourier series initial condition
    1. Use random coefficients for sin and cos terms
    2. Ensure the result is normalized to [-1, 1]
    """
    if seed is not None:
        np.random.seed(seed)

    if n_modes is None:
        n_modes = np.random.randint(7, 20)

    # Generate coefficients for Fourier series
    sin_coeff = np.random.normal(size=n_modes)
    cos_coeff = np.random.normal(size=n_modes)

    # Prepare frequency modes, shape: (n_modes,)
    modes = np.arange(1, n_modes + 1)

    # Broadcast x to shape (1, len(x)) and modes to (n_modes, 1)
    # Then compute sin(...) and cos(...) of shape (n_modes, len(x))
    sin_part = sin_coeff[:, None] * np.sin(modes[:, None] * np.pi * x[None, :])
    cos_part = cos_coeff[:, None] * np.cos(modes[:, None] * np.pi * x[None, :])

    # Sum over n_modes to get a 1D result of shape (len(x),)
    u0 = sin_part.sum(axis=0) + cos_part.sum(axis=0)

    # Normalize to [-1, 1]
    min_val, max_val = u0.min(), u0.max()

    # Guard against potential zero denominator when max_val == min_val
    if max_val == min_val:
        return np.zeros_like(u0)  # All zeros if the function is constant

    u0 = (u0 - min_val) / (max_val - min_val)  # [0, 1]
    u0 = 2.0 * u0 - 1.0                        # [-1, 1]
    return u0


def generate_gmm_ic(x, n_components=None, seed=None):
    """
    Generate Gaussian mixture model initial condition using vectorized operations.

    1. Random number of components if n_components is None
    2. Use random means, variances, and weights
    3. Ensure result is normalized to [-1, 1]
    """
    if seed is not None:
        np.random.seed(seed)

    if n_components is None:
        n_components = np.random.randint(5, 15) # this is very smooth so we want to have more components

    # Generate means, variances, and weights
    means = np.random.uniform(-1, 1, size=n_components)
    variances = np.random.uniform(0.001, 0.001, size=n_components)
    weights = np.random.uniform(-1, 1, size=n_components)

    # Vectorized computation of GMM
    # Shape: (n_components, 1) for means, variances, and weights,
    #        plus (1, len(x)) for x.
    # We get a (n_components, len(x)) array of Gaussians, then sum across components.
    diff_sq = (x[None, :] - means[:, None])**2
    exps = np.exp(-diff_sq / (2 * variances[:, None]))  # shape (n_components, len(x))
    weighted_exps = weights[:, None] * exps
    u0 = weighted_exps.sum(axis=0)  # sum across n_components, shape (len(x),)

    # Normalize to [-1, 1]
    min_val, max_val = u0.min(), u0.max()
    if max_val == min_val:
        # Handle corner case if all Gaussians sum to constant
        return np.zeros_like(u0)

    u0 = (u0 - min_val) / (max_val - min_val)  # [0, 1]
    u0 = 2.0 * u0 - 1.0                        # [-1, 1]

    return u0


def generate_piecewise_ic(x, n_pieces=None, seed=None):
    """
    Generate a piecewise linear initial condition with periodic boundary conditions on x ∈ [-1, 1].
    Specifically:
      1) The function satisfies u(-1) = u(1).
      2) If x is outside [-1, 1], we wrap it back into the interval (mod 2).
      3) Between the sorted breakpoints b[i] and b[i+1], interpolate linearly.
    """
    if seed is not None:
        np.random.seed(seed)

    if n_pieces is None:
        n_pieces = np.random.randint(15, 40)

    # 1. Generate random breakpoints in (-1, 1), plus fix the endpoints at -1 and 1.
    #    We'll then sort them. This ensures the domain covers the entire [-1, 1].
    breakpoints = np.random.uniform(-1, 1, size=n_pieces)
    breakpoints[0]  = -1.0
    breakpoints[-1] =  1.0
    breakpoints = np.sort(breakpoints)

    # 2. Generate random function values for each breakpoint.
    values = np.random.uniform(-1, 1, size=n_pieces)
    # Enforce periodicity: value at x=-1 equals value at x=1.
    values[-1] = values[0]

    # 3. Precompute slopes for intervals [b[i], b[i+1]].
    #    slopes[i] = (values[i+1] - values[i]) / (b[i+1] - b[i])
    slopes = (values[1:] - values[:-1]) / (breakpoints[1:] - breakpoints[:-1])

    # 4. "Wrap" x into the domain [-1,1) using modulo 2 arithmetic:
    #    x_wrapped = ((x + 1) mod 2) - 1
    #    so anything less than -1 or greater than 1 is wrapped back.
    x_wrapped = (x + 1.0) % 2.0 - 1.0

    # (Optional) If x_wrapped == 1.0, shift it slightly so it doesn't exceed b[-1].
    # This prevents searchsorted from going out of range if x_wrapped equals exactly 1.0.
    mask_exact_one = (x_wrapped == 1.0)
    x_wrapped[mask_exact_one] = 1.0 - 1e-14

    # 5. Determine the piecewise interval for each x_wrapped
    #    side='right' => if x == b[i], we consider it in interval i rather than i-1
    #    subtract 1 => so that idx = i means  b[i] ≤ x < b[i+1]
    idx = np.searchsorted(breakpoints, x_wrapped, side='right') - 1

    # Clip idx so it cannot exceed n_pieces - 2
    # (the last interval is [b[n_pieces-2], b[n_pieces-1]] )
    idx_clipped = np.clip(idx, 0, n_pieces - 2)

    # 6. Piecewise linear interpolation:
    #      u(x) = values[i] + slopes[i] * (x - b[i])
    u0 = values[idx_clipped] + slopes[idx_clipped] * (x_wrapped - breakpoints[idx_clipped])

    return u0


def allen_cahn_rhs(t, u, epsilon, x_grid):
    """TODO: Implement Allen-Cahn equation RHS:
        ∂u/∂t = Δu - (1/ε²)(u³ - u)
    """
    dx = x_grid[1] - x_grid[0]

    # TODO: Compute Laplacian (Δu) with periodic boundary conditions
    laplacian = (np.roll(u, -1) - 2*u + np.roll(u, 1)) / dx**2

    # TODO: Compute nonlinear term -(1/ε²)(u³ - u)
    nonlinear = -1 / epsilon**2 * (u**3 - u)

    # TODO: Return full RHS
    return laplacian + nonlinear

def generate_dataset(n_samples, epsilon, x_grid, t_eval, ic_type='fourier', seed=None):
    """Generate dataset for Allen-Cahn equation."""
    if seed is not None:
        np.random.seed(seed)

    # Initialize dataset array
    dataset = np.zeros((n_samples, len(t_eval), len(x_grid)))

    # Generate samples
    for i in range(n_samples):
        # Generate initial condition based on type
        if ic_type == 'fourier':
            u0 = generate_fourier_ic(x_grid, seed=seed+i if seed else None)
        elif ic_type == 'gmm':
            u0 = generate_gmm_ic(x_grid, seed=seed+i if seed else None)
        elif ic_type == 'piecewise':
            u0 = generate_piecewise_ic(x_grid, seed=seed+i if seed else None)
        else:
            raise ValueError(f"Unknown IC type: {ic_type}")

        # Solve PDE using solve_ivp
        sol = solve_ivp(
            allen_cahn_rhs,
            t_span=(t_eval[0], t_eval[-1]),
            y0=u0,
            t_eval=t_eval,
            args=(epsilon, x_grid),
            method='RK45',
            rtol=1e-6,
            atol=1e-6
        )

        dataset[i] = sol.y.T

    return dataset

def generate_training_and_val_files():
    """Generate all datasets."""

    train_data = []
    val_data = []

    # Generate training datasets. want to end up with a mapping from eps to [n_samples * |ic_types|, |t_eval|, x_grid]
    for epsilon in epsilons:
        train_data_eps = []
        for ic_type in ic_types:
            train_data_eps.append(generate_dataset(n_train, epsilon, x_grid, t_eval, ic_type, seed=base_seed))
        train_data.append(np.concatenate(train_data_eps, axis=0))

        val_data_eps = []
        for ic in ic_types:
            val_data_eps.append(generate_dataset(n_test, epsilon, x_grid, t_eval, ic, seed=base_seed))
        val_data.append(np.concatenate(val_data_eps, axis=0))

    # Generate additional validation datasets
    for epsilon in additional_val_epsilons:
        val_data_eps = []
        for ic in ic_types:
            val_data_eps.append(generate_dataset(n_test, epsilon, x_grid, t_eval, ic, seed=base_seed))
        val_data.append(np.concatenate(val_data_eps, axis=0))

    print("train data shape: ", np.array(train_data).shape)



    # Save datasets as numpy files
    train_data = np.array(train_data)
    val_data = np.array(val_data)


    # Save datasets as numpy files
    np.save('train_data.npy', train_data, allow_pickle=True)
    print("train data shape: ", train_data.shape)


    np.save('val_data.npy', val_data, allow_pickle=True)
    print("val data shape: ", val_data.shape)

    return

def are_eps_sensible():
    """
        for the smallest and the largest epsilon values, for each IC type, solve one AC equatiion and plot the results to see if they are changing over time.
        for a too big or too small epsion, the solution would remain constant after 0.25
    """
    small_eps = epsilons[0]
    large_eps = epsilons[-1]

    # generate two plots one for small epsilon and one for large epsilon
    # on each plot have 3 subplots for each IC type
    # on each plot have 5 lines for each time step

    fig, axs = plt.subplots(2, 3, figsize=(15, 10))
    fig.suptitle("Solutions for small and large epsilon values")

    for i, ic_type in enumerate(ic_types):
        # Small epsilon
        u = generate_dataset(1, small_eps, x_grid, t_eval, ic_type, seed=base_seed )[0]

        for j in range(len(t_eval)):
            axs[0, i].plot(x_grid, u[j], label=f"t={t_eval[j]}")
        axs[0, i].set_title(f"{ic_type} IC, epsilon={small_eps}")
        axs[0, i].legend()

        # Large epsilon
        u_large = generate_dataset(1, large_eps, x_grid, t_eval, ic_type, seed=base_seed )[0]

        for j in range(len(t_eval)):
            axs[1, i].plot(x_grid, u_large[j], label=f"t={t_eval[j]}")
        axs[1, i].set_title(f"{ic_type} IC, epsilon={large_eps}")
        axs[1, i].legend()

    plt.show()
    return




# Set up spatial grid
nx = 128
x_grid = np.linspace(-1, 1, nx)

# Set up temporal grid
t_eval = np.array([0.0, 0.25, 0.50, 0.75, 1.0])

# scaling of the time to make it more interesting -- the phase separation happens at [0,0.5] for eps ~~ 1e-3
TIME_SCALE = 1000
t_eval = t_eval / TIME_SCALE


# Parameters for datasets
ic_types = ['fourier', 'gmm', 'piecewise']  # Different initial condition types

epsilons = [0.01, 0.02, 0.05, 0.07, 0.1]  # Different epsilon values; should be in the range 0.01, 0.1 with this time scaling

n_train = 400   # Number of training samples per configuration
n_test = 20     # Number of test samples
base_seed = 40  # For reproducibility
additional_val_epsilons = [0.03, 0.005]  # Additional epsilons for validation

are_eps_sensible()
generate_training_and_val_files()
# Out:
# train data shape:  (5, 1200, 5, 128)
# train data shape:  (5, 1200, 5, 128)
# val data shape:  (7, 60, 5, 128)

# %%
import math
class SpectralConv1d(nn.Module):
    """
        1D Fourier layer. It does FFT, linear transform, and Inverse FFT.
    """
    def __init__(self, in_channels, out_channels, modes1):
        super(SpectralConv1d, self).__init__()

        self.in_channels = in_channels
        self.out_channels = out_channels
        self.modes1 = modes1
        self.scale = (1 / (in_channels * out_channels))
        self.weights1 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, dtype=torch.cfloat))

    # Complex multiplication
    def compl_mul1d(self, input, weights):
        # (batch, in_channel, x ), (in_channel, out_channel, x) -> (batch, out_channel, x)
        return torch.einsum("bix,iox->box", input, weights)

    def forward(self, x):
        batchsize = x.shape[0]
        # x.shape == [batch_size, in_channels, number of grid points]

        # Compute Fourier coefficients
        x_ft = torch.fft.rfft(x)

        # Multiply relevant Fourier modes
        out_ft = torch.zeros(batchsize, self.out_channels, x.size(-1) // 2 + 1, device=x.device, dtype=torch.cfloat)
        out_ft[:, :, :self.modes1] = self.compl_mul1d(x_ft[:, :, :self.modes1], self.weights1)

        # Return to physical space
        return torch.fft.irfft(out_ft, n=x.size(-1))



class FNOBlock(nn.Module):
    def __init__(self, modes, width):
        super().__init__()
        # TODO: Initialize the FNO block components
        # Should include:
        # - Spectral convolution
        # - Pointwise convolution
        # - Normalization (if needed)
        self.modes = modes
        self.width = width
        self.spectral_layer = SpectralConv1d(self.width, self.width, self.modes)
        self.conv_layer = nn.Conv1d(self.width, self.width, 1)

        self.activation = nn.ReLU()


    def forward(self, x):
        # TODO: Implement the FNO block forward pass
        # Remember to include skip connections

        out_spectral = self.spectral_layer(x)
        out_conv = self.conv_layer(x)
        x = x + out_spectral + out_conv
        x = self.activation(x)
        return x



class TimeEmbedding_learnable(nn.Module):
    def __init__(self, embedding_dim):
        super().__init__()
        # TODO: Initialize time embedding
        # Consider using positional encoding or a learnable embedding

        # NOTE: using a learnable time embedding:
        # time as input is of size (batch_size, 1)
        self.linear1 = nn.Linear(1, 4 * embedding_dim)  # first linear layer: (batch_size, 1) --> (batch_size, 4 * embedding_dim)
        self.linear2 = nn.Linear(4 * embedding_dim, 2 * embedding_dim)  # second linear layer: (batch_size, 4 * embedding_dim) -> (batch_size, 2 * embedding_dim)
        self.linear3 = nn.Linear(2 * embedding_dim, embedding_dim) # third linear layer: (batch_size, 2 * embedding_dim) -> (batch_size, 1 * embedding_dim)
        # Add activation functions between layers
        self.activation = nn.SiLU()  # Also known as Swish, works well for embeddings

    def forward(self, t):
        # TODO: Implement time embedding
        # t shape: (batch_size, 1)
        # return shape: (batch_size, embedding_dim)
        x = self.activation(self.linear1(t))
        x = self.activation(self.linear2(x))
        x = self.linear3(x)
        # return shape: (batch_size, embedding_dim)
        return x

class TimeEmbedding(nn.Module):
    def __init__(self, embedding_dim):
        super().__init__()
        self.embedding_dim = embedding_dim

    def forward(self, t):
        """
        Args:
            t: A tensor of shape (batch_size, 1) containing time steps.

        Returns:
            A sinusoidal time embedding of shape (batch_size, embedding_dim).
        """
        # time is scaled by 1/1000 so first let us normalise it
        t *= TIME_SCALE
        # We'll split the embedding dimension in half: one for sine, one for cosine
        half_dim = self.embedding_dim // 2

        # Create a range of frequencies for the sinusoidal functions
        # shape: (half_dim,)
        freq = torch.exp(
            -math.log(10000) * torch.arange(0, half_dim, dtype=torch.float32, device=t.device) / half_dim
        )

        # Multiply time steps by these frequencies
        # shape of t is (batch_size, 1) and freq is (half_dim,)
        # after broadcasting, pos will be (batch_size, half_dim)
        pos = t.float() * freq.unsqueeze(0)

        # Compute the sin and cos parts
        sin_part = torch.sin(pos)
        cos_part = torch.cos(pos)

        # Concatenate along the last dimension to get (batch_size, embedding_dim)
        return torch.cat([sin_part, cos_part], dim=-1)


class AllenCahnFNO(nn.Module):
    def __init__(self, modes=16, width=64, n_layers = 3):
        super().__init__()
        self.modes = modes
        self.width = width

        # TODO: Initialize model components
        # Consider:
        # - Epsilon embedding
        # - Time embedding
        # - Input/output layers
        # - FNO blocks

        # Time and epsilon embeddings
        self.time_embed = TimeEmbedding(embedding_dim=width)

        # a more complicated eps embedding:
        self.eps_embed = nn.Sequential(
            nn.Linear(1, 10),
            nn.SiLU(),
            nn.Linear(10, 20),
            nn.SiLU(),
            nn.Linear(20, width),
            nn.SiLU(),
            nn.Linear(width, width)
        )

        self.time_emb_linear = nn.Sequential(
            nn.Linear(width, width),
            nn.SiLU()
        )


        # Initial processing of spatial input
        self.fc0 = nn.Linear(1, width)  # lift spatial dimension to width

        # FNO blocks
        self.fno_blocks = nn.ModuleList([
            FNOBlock(modes=modes, width=width)
            for _ in range(n_layers)
        ])

        # Final output layer
        self.fc1 = nn.Linear(width, 128)
        self.fc2 = nn.Linear(128, 1)

    def forward(self, x, eps, t):
        """
        Args:
            x: Initial condition (batch_size, x_size)
            eps: Epsilon values (batch_size, 1)
            t: Time points (batch_size, n_steps)
        Returns:
            Predictions at requested timepoints (batch_size, n_steps, x_size)
        """
        # TODO: Implement the full model forward pass
        # 1. Embed epsilon and time
        # 2. Process spatial information with FNO blocks
        # 3. Generate predictions for each timestep

        batch_size, x_size = x.shape
        n_steps = t.shape[1]

        # Embed epsilon
        eps_embedded = self.eps_embed(eps)  # (batch_size, width)

        # Process initial condition
        x = x.unsqueeze(-1)     # (batch_size, x_size, 1)
        x = self.fc0(x)         # (batch_size, x_size, width)
        x = x.permute(0, 2, 1)  # (batch_size, width, x_size)

        # Initialize output tensor
        out = torch.zeros(batch_size, n_steps, x_size, device=x.device)

        # Process each timestep
        for i in range(n_steps):
            # Embed current timestep
            t_i = t[:, i:i+1]  # (batch_size, 1)
            t_embedded = self.time_embed(t_i)  # (batch_size, width)
            t_embedded = self.time_emb_linear(t_embedded) # (batch_size, width)
            # Add time and epsilon embeddings to spatial features
            x_t = x + t_embedded.unsqueeze(-1) + eps_embedded.unsqueeze(-1)

            # Apply FNO blocks
            for block in self.fno_blocks:
                x_t = block(x_t)

            # Project to output space
            x_t = x_t.permute(0, 2, 1)  # (batch_size, x_size, width)
            x_t = F.gelu(self.fc1(x_t))
            x_t = self.fc2(x_t)
            out[:, i] = x_t.squeeze(-1)

        return out

def get_loss_func():
    """
    TODO: Define custom loss function(s) for training
    Consider:
    - L2 loss on predictions
    - Physical constraints (energy, boundaries)
    - Gradient-based penalties
    """
    def loss_function(pred, target, eps):
            # L2 loss on predictions
            mse_loss = F.mse_loss(pred, target)

            # Add physical constraints
            # Gradient-based penalty for smoothness
            eps = eps.unsqueeze(1).unsqueeze(1)

            spatial_gradients = torch.gradient(pred, dim=-1)[0]
            smoothness_loss = torch.mean(spatial_gradients**2)

            # Energy constraint for Allen-Cahn
            # The energy functional is ∫ (ε²/2)|∇u|² + (1/4)(u² - 1)² dx
            energy_density = (eps**2/2) * spatial_gradients**2 + 0.25 * (pred**2 - 1)**2
            energy_loss = torch.mean(energy_density)

            # Combine the usual MSE loss with the other components if needed
            total_loss = mse_loss   + 0.1 * smoothness_loss + 0.01 * energy_loss
            return total_loss

    return loss_function

def get_optimizer(model):
    """
    TODO: Configure optimizer and learning rate schedule
    Consider:
    - Adam with appropriate learning rate
    - Learning rate schedule for curriculum
    """
    # Adam optimizer with learning rate schedule
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

    # Learning rate scheduler with warm-up and cosine decay
    scheduler = torch.optim.lr_scheduler.OneCycleLR(
        optimizer,
        max_lr=1e-3,
        epochs=100,  # adjust based on your training setup
        steps_per_epoch=100,  # adjust based on your dataset size
        pct_start=0.1,  # warm-up period
        anneal_strategy='cos'
    )

    return optimizer, scheduler

def train_step(model, batch, optimizer, loss_func):
    model.train()
    optimizer.zero_grad()

    # 'batch' is a dictionary with keys: 'initial', 'epsilon', 'times', 'target'
    x = batch["initial"]   # shape (B, x_size)
    eps = batch["epsilon"] # shape (B, 1)
    t = batch["times"]     # shape (B, n_timesteps)
    target = batch["target"] # shape (B, n_timesteps, x_size)

    pred = model(x, eps, t)
    loss = loss_func(pred, target, eps)

    loss.backward()
    torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
    optimizer.step()

    return loss.item()

def validation_step(model, batch, loss_func):
    model.eval()
    with torch.no_grad():
        x = batch["initial"]
        eps = batch["epsilon"]
        t = batch["times"]
        target = batch["target"]

        pred = model(x, eps, t)
        loss = loss_func(pred, target, eps)

    return loss.item()


# Example usage:
def debug_model():
     # Model initialization
    model = AllenCahnFNO(modes=16, width=64)

    # Get loss function and optimizer
    loss_func = get_loss_func()
    optimizer, scheduler = get_optimizer(model)

    # Sample data
    batch_size, x_size = 32, 128
    x = torch.randn(batch_size, x_size)
    eps = torch.randn(batch_size, 1)
    t = torch.linspace(0, 1, 4)[None].expand(batch_size, -1)
    target = torch.randn(batch_size, 4, x_size)  # Example target data

    # Create batch
    batch = (x, eps, t, target)

    # Training step
    train_loss = train_step(model, batch, optimizer, loss_func)
    print(f"Training loss: {train_loss}")

    # Validation step
    val_loss = validation_step(model, batch, loss_func)
    print(f"Validation loss: {val_loss}")

# debug_model()

# %%
class AllenCahnDataset(Dataset):
    def __init__(self, data, epsilon_values, time_points):
        """
        Args:
            data (np.ndarray): shape (num_epsilons, num_samples, num_timesteps, num_points)
                For example, if you have 3 epsilons, 10 samples each, 5 time steps,
                and 128 spatial points, then data.shape = (3, 10, 5, 128)

            epsilon_values (list or np.ndarray): shape (num_epsilons,)
                The corresponding epsilon values, e.g., [0.1, 0.05, 0.02]

            time_points (np.ndarray): shape (num_timesteps,)
                The time points at which the PDE solution is recorded,
                e.g. [0.0, 0.25, 0.5, 0.75, 1.0]
        """
        self.data = data
        self.epsilon_values = list(epsilon_values)  # ensure it's indexable
        self.time_points = time_points

        print("epsilon values: ", self.epsilon_values)

        # Build the list of valid (eps_index, sample_idx) pairs
        self.indices = []
        for eps_idx in range(len(self.epsilon_values)):
            num_samples = self.data[eps_idx].shape[0]
            for sample_idx in range(num_samples):
                self.indices.append((eps_idx, sample_idx))

        print("len of current indices: ", len(self.indices))

    def __len__(self):
        return len(self.indices)

    def __getitem__(self, idx):
        # Retrieve the integer indices for epsilon and sample
        eps_index, sample_index = self.indices[idx]

        # Grab the trajectory for that epsilon/sample:
        # shape = (num_timesteps, num_points)
        trajectory = self.data[eps_index][sample_index]

        # Convert everything to torch.Tensor
        # "initial" = PDE solution at the first time point
        # "target"  = PDE solution at subsequent time points
        # "epsilon" = the float epsilon value
        # "times"   = the set of times for the target states
        sample = {
            'initial': torch.FloatTensor(trajectory[0]),     # shape: (num_points,)
            'target':  torch.FloatTensor(trajectory[1:]),    # shape: (num_timesteps-1, num_points)
            'epsilon': torch.FloatTensor([self.epsilon_values[eps_index]]),
            'times':   torch.FloatTensor(self.time_points[1:])  # shape: (num_timesteps-1,)
        }
        return sample

def create_subset_dataset(full_data, full_eps, subset_eps, time_points):
    """
    Given the full data array and list of all epsilons,
    create a new AllenCahnDataset for the subset of epsilons.
    """
    # 1) Find the indices of the desired epsilons in the full list
    subset_eps = np.array(subset_eps)
    print("creating a subset dataset for subset_eps:", subset_eps)
    # converting elements of subset_eps to numpy.float64
    subset_indices = [full_eps.index(np.float64(eps)) for eps in subset_eps]
    # 2) Slice the data for just those indices
    #    shape becomes (len(subset_indices), num_samples, num_timesteps, num_points)
    subset_data = full_data[subset_indices]
    # 3) Create a dataset with the smaller data array and smaller eps list
    return AllenCahnDataset(subset_data, subset_eps, time_points)

def train_model(model,
                train_data,
                val_data,
                epsilon_values,
                time_points,
                batch_size=32,
                epochs=100,
                device='cuda',
                learning_rate=1e-3,
                curriculum_steps=None):
    """
    Training loop with curriculum learning on epsilon values.

    curriculum_steps: list of (epoch, epsilon_subset) tuples
                     e.g., [(0, [0.1]), (20, [0.1, 0.05]), ...]
    """

    optimizer, scheduler = get_optimizer(model)
    best_val_loss = float('inf')

    val_dataset = AllenCahnDataset(val_data, epsilon_values, time_points)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    for epoch in range(epochs):

        # Curriculum Step: if we have a scheduled change in the subset of epsilons
        if curriculum_steps:
            for step_epoch, eps_subset in curriculum_steps:
                if epoch == step_epoch:
                    # Ensure eps_subset is always a list or 1-dimensional array
                    eps_subset = eps_subset if isinstance(eps_subset, (list, np.ndarray)) else [eps_subset]

                    train_dataset = create_subset_dataset(train_data,
                                                          epsilon_values,
                                                          eps_subset,
                                                          time_points)
                    train_loader = DataLoader(train_dataset,
                                              batch_size=batch_size,
                                              shuffle=True)
                    print(f"Curriculum update: now training on epsilon values {eps_subset}")

        # Training
        model.train()
        train_loss = 0
        for batch in train_loader:
            batch = {k: v.to(device) for k, v in batch.items()}
            loss = train_step(model, batch, optimizer, get_loss_func())
            train_loss += loss

        # Validation
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for batch in val_loader:
                batch = {k: v.to(device) for k, v in batch.items()}
                loss = validation_step(model, batch, get_loss_func())
                val_loss += loss

        train_loss /= len(train_loader)
        val_loss   /= len(val_loader)

        print(f"Epoch {epoch}: train_loss={train_loss:.6f}, val_loss={val_loss:.6f}")

        scheduler.step(val_loss)

        # Save best model
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), 'best_model.pt')

    return model

# NOTE: tried to run it locally on Apple Silicon using mps but the complex multiplication in the SpectralConv1d is not supported
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print("Using device:", device)



# load the datasets:
train_data = np.load('train_data.npy', allow_pickle=True)
val_data = np.load('val_data.npy', allow_pickle=True)

print("train dataset shape: ", train_data.shape)
print("test dataset shape: ", val_data.shape)


# initialise an FNO and train it using the proposed curriculum:
model = AllenCahnFNO(modes=16, width=64)
model = model.to(device)

epsilon_values = epsilons
time_points = t_eval

epsilon_values = sorted(epsilon_values, reverse = True )
print("epsilon values: ", epsilon_values)
# Example curriculum steps
fixed_curriculum = [
    (0, epsilon_values[0]),         # Start with largest epsilon
    (20, epsilon_values[0:2]),      # Add medium epsilon
    (40, epsilon_values[0:3]),      # Add smallest epsilon
    (60, epsilon_values) # everything!
]

# Training
trained_model = train_model(
    model, train_data, val_data, epsilon_values, time_points,
    batch_size=32, epochs=140, device= device,
    curriculum_steps= fixed_curriculum
)
# Out:
# Using device: cpu
# train dataset shape:  (5, 1200, 5, 128)
# test dataset shape:  (7, 60, 5, 128)
# epsilon values:  [0.1, 0.07, 0.05, 0.02, 0.01]
# epsilon values:  [0.1, 0.07, 0.05, 0.02, 0.01]
# len of current indices:  300
# creating a subset dataset for subset_eps: [0.1]
# epsilon values:  [0.1]
# len of current indices:  1200
# Curriculum update: now training on epsilon values [0.1]
# Epoch 0: train_loss=0.801731, val_loss=0.262917
# /opt/anaconda3/envs/AISE/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:243: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Epoch 1: train_loss=0.568464, val_loss=0.138682
# Epoch 2: train_loss=0.338454, val_loss=0.112283
# Epoch 3: train_loss=0.195836, val_loss=0.192455
# Epoch 4: train_loss=0.152935, val_loss=0.158036
# Epoch 5: train_loss=0.127658, val_loss=0.163647
# Epoch 6: train_loss=0.108383, val_loss=0.171722
# Epoch 7: train_loss=0.092091, val_loss=0.170347
# Epoch 8: train_loss=0.079581, val_loss=0.180783
# Epoch 9: train_loss=0.069908, val_loss=0.195778
# Epoch 10: train_loss=0.062839, val_loss=0.207139
# Epoch 11: train_loss=0.057833, val_loss=0.211934
# Epoch 12: train_loss=0.053621, val_loss=0.206565
# Epoch 13: train_loss=0.049912, val_loss=0.211836
# Epoch 14: train_loss=0.046881, val_loss=0.209615
# Epoch 15: train_loss=0.044988, val_loss=0.210232
# Epoch 16: train_loss=0.043024, val_loss=0.215238
# Epoch 17: train_loss=0.041431, val_loss=0.218095
# Epoch 18: train_loss=0.039913, val_loss=0.211147
# Epoch 19: train_loss=0.038627, val_loss=0.212909
# creating a subset dataset for subset_eps: [0.1  0.07]
# epsilon values:  [0.1, 0.07]
# len of current indices:  2400
# Curriculum update: now training on epsilon values [0.1, 0.07]
# Epoch 20: train_loss=0.054035, val_loss=0.132354
# Epoch 21: train_loss=0.050351, val_loss=0.145058
# Epoch 22: train_loss=0.049265, val_loss=0.142596
# Epoch 23: train_loss=0.048743, val_loss=0.139906
# Epoch 24: train_loss=0.048219, val_loss=0.137428
# Epoch 25: train_loss=0.047720, val_loss=0.137478
# Epoch 26: train_loss=0.047352, val_loss=0.138375
# Epoch 27: train_loss=0.046766, val_loss=0.129936
# Epoch 28: train_loss=0.046583, val_loss=0.135956
# Epoch 29: train_loss=0.046591, val_loss=0.138596
# Epoch 30: train_loss=0.045902, val_loss=0.126595
# Epoch 31: train_loss=0.045852, val_loss=0.137796
# Epoch 32: train_loss=0.045436, val_loss=0.138590
# Epoch 33: train_loss=0.045068, val_loss=0.142820
# Epoch 34: train_loss=0.044964, val_loss=0.131849
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 176
#     168 fixed_curriculum = [
#     169     (0, epsilon_values[0]),         # Start with largest epsilon
#     170     (20, epsilon_values[0:2]),      # Add medium epsilon
#     171     (40, epsilon_values[0:3]),      # Add smallest epsilon
#     172     (60, epsilon_values) # everything!
#     173 ]
#     175 # Training
# --> 176 trained_model = train_model(
#     177     model, train_data, val_data, epsilon_values, time_points,
#     178     batch_size=32, epochs=140, device= device,
#     179     curriculum_steps= fixed_curriculum
#     180 )
#
# Cell In[6], line 117, in train_model(model, train_data, val_data, epsilon_values, time_points, batch_size, epochs, device, learning_rate, curriculum_steps)
#     115 for batch in train_loader:
#     116     batch = {k: v.to(device) for k, v in batch.items()}
# --> 117     loss = train_step(model, batch, optimizer, get_loss_func())
#     118     train_loss += loss
#     120 # Validation
#
# Cell In[5], line 282, in train_step(model, batch, optimizer, loss_func)
#     279 t = batch["times"]     # shape (B, n_timesteps)
#     280 target = batch["target"] # shape (B, n_timesteps, x_size)
# --> 282 pred = model(x, eps, t)
#     283 loss = loss_func(pred, target, eps)
#     285 loss.backward()
#
# File /opt/anaconda3/envs/AISE/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/AISE/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# Cell In[5], line 210, in AllenCahnFNO.forward(self, x, eps, t)
#     208 # Apply FNO blocks
#     209 for block in self.fno_blocks:
# --> 210     x_t = block(x_t)
#     212 # Project to output space
#     213 x_t = x_t.permute(0, 2, 1)  # (batch_size, x_size, width)
#
# File /opt/anaconda3/envs/AISE/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/AISE/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# Cell In[5], line 57, in FNOBlock.forward(self, x)
#      52 def forward(self, x):
#      53     # TODO: Implement the FNO block forward pass
#      54     # Remember to include skip connections
#      56     out_spectral = self.spectral_layer(x)
# ---> 57     out_conv = self.conv_layer(x)
#      58     x = x + out_spectral + out_conv
#      59     x = self.activation(x)
#
# File /opt/anaconda3/envs/AISE/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/AISE/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /opt/anaconda3/envs/AISE/lib/python3.12/site-packages/torch/nn/modules/conv.py:375, in Conv1d.forward(self, input)
#     374 def forward(self, input: Tensor) -> Tensor:
# --> 375     return self._conv_forward(input, self.weight, self.bias)
#
# File /opt/anaconda3/envs/AISE/lib/python3.12/site-packages/torch/nn/modules/conv.py:370, in Conv1d._conv_forward(self, input, weight, bias)
#     358 if self.padding_mode != "zeros":
#     359     return F.conv1d(
#     360         F.pad(
#     361             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     368         self.groups,
#     369     )
# --> 370 return F.conv1d(
#     371     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     372 )
#
# KeyboardInterrupt:

# %%
# Evaluate the trained model, compare to the ground truth on three samples
trained_model.eval()

batch_size_for_plotting = 5

# Create a test dataset/loader (example uses train_data, but use val_data if preferred)
test_dataset = AllenCahnDataset(train_data, epsilon_values, time_points)
test_loader = DataLoader(test_dataset, batch_size=batch_size_for_plotting, shuffle=True)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Grab one batch of size 'batch_size_for_plotting'
batch = next(iter(test_loader))
batch = {k: v.to(device) for k, v in batch.items()}

initial = batch['initial']  # shape: (B, x_size)
epsilon = batch['epsilon']  # shape: (B, 1)
times   = batch['times']    # shape: (B, n_timesteps - 1)
target  = batch['target']   # shape: (B, n_timesteps - 1, x_size)

# Forward pass: pred shape = (B, n_timesteps - 1, x_size)
pred = trained_model(initial, epsilon, times)

# Randomly choose 3 indices (or just [0,1,2] if you prefer)
ind_for_plot = np.random.choice(pred.shape[0], 3, replace=False)
print("ind_for_plot:", ind_for_plot)

# Assume PDE solutions are 1D in space with x_size points
x_size = target.shape[-1]
x_grid = np.linspace(-1, 1, x_size)  # or adapt to your domain
# Create a 3×(1 + pred.shape[1]) = 3×5 figure
fig, axs = plt.subplots(nrows=3, ncols=1 + pred.shape[1], figsize=(15, 9))

for row, i in enumerate(ind_for_plot):
    # row is 0,1,2 for your 3 chosen samples
    eps_val = epsilon[i].item()  # for labeling
    for col in range(1 + pred.shape[1]):
        ax = axs[row, col]

        if col == 0:
            # Plot the initial condition
            ax.plot(x_grid, initial[i].detach().cpu().numpy(), label='Initial')
            # Title can show "Sample i, eps, t=0"
            ax.set_title(f"Sample {i}\nEps={eps_val:.3f}, t=0.0")
            ax.set_ylabel("u(x)")
            ax.legend()
        else:
            # col in [1..4] => indexes pred.shape[1] = 4
            t_val = times[i, col-1].item()

            # Plot ground truth
            ax.plot(x_grid, target[i, col-1].detach().cpu().numpy(), label='Truth')
            # Plot prediction
            ax.plot(x_grid, pred[i, col-1].detach().cpu().numpy(), '--', label='Pred')

            # Title
            ax.set_title(f"Eps={eps_val:.3f}, t={t_val:.3f}")

            # Only put a legend in the last column if you like
            if col == pred.shape[1]:
                ax.legend()

plt.tight_layout()
plt.show()
# Out:
# epsilon values:  [0.1, 0.07, 0.05, 0.02, 0.01]
# len of current indices:  6000
# ind_for_plot: [1 2 3]

# %%
# 1) Evaluate on the entire test/val dataset
test_dataset = AllenCahnDataset(val_data, epsilon_values, time_points)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
trained_model.eval()

# Helper: Round (eps, time) to avoid floating-point mismatch
def round_key(e, t, digits=6):
    """Rounds eps and time to 'digits' decimals to avoid mismatch in dictionary keys."""
    return (round(float(e), digits), round(float(t), digits))

# 2) Create dictionaries to accumulate sums of errors and counts
all_errors = {}
all_counts = {}

def rel_error(pred, tgt):
    """Compute relative L2 error."""
    return torch.norm(pred - tgt) / torch.norm(tgt)

with torch.no_grad():
    for batch in test_loader:
        # Move batch to device
        batch = {k: v.to(device) for k, v in batch.items()}

        # Extract inputs and forward pass
        initial = batch['initial']  # (B, x_size)
        eps     = batch['epsilon']  # (B, 1)
        times   = batch['times']    # (B, n_timesteps-1)
        target  = batch['target']   # (B, n_timesteps-1, x_size)
        pred    = trained_model(initial, eps, times)  # (B, n_timesteps-1, x_size)

        B, T, X = pred.shape  # B=Batch size, T=#time points, X=#spatial points

        # 3) Accumulate errors for each (eps_val, t_val)
        for i in range(B):
            eps_val = eps[i].item()
            for t in range(T):
                t_val = times[i, t].item()
                error_val = rel_error(pred[i, t], target[i, t]).item()

                # Round (eps_val, t_val) to avoid small floating mismatches
                key = round_key(eps_val, t_val, digits=6)

                if key not in all_errors:
                    all_errors[key] = 0.0
                    all_counts[key] = 0

                all_errors[key] += error_val
                all_counts[key] += 1

# 4) Compute the average errors
for key in all_errors:
    all_errors[key] /= all_counts[key]
    print(f"Average error for eps={key[0]}, t={key[1]}: {all_errors[key]}")
    print(f"counted { all_counts[key] } instances of this")
 # 5) Print out as a table: rows = eps, columns = time
unique_eps = sorted(test_dataset.epsilon_values)

# Suppose test_dataset.time_points is [0, 0.00025, 0.0005, 0.00075, 0.001]
# We skip the first entry (0.0) and rescale by 1000 => [0.25, 0.5, 0.75, 1.0]
raw_times = test_dataset.time_points[1:]  # e.g. [0.00025, 0.0005, 0.00075, 0.001]
unique_times = [round(t * 1000, 6) for t in raw_times]  # => [0.25, 0.5, 0.75, 1.0]

print("unique eps", unique_eps)
print("unique times", unique_times)

# Header row
print(" " * 10, end="")
for t_val in unique_times:
    print(f"  t={t_val}", end="")
print()

# For each eps row
for e_val in unique_eps:
    print(f"eps={e_val:5.3f}", end="")
    for t_val in unique_times:
        # We must use the same rounding we used during accumulation of errors:
        # i.e. if times were 0.25 in the dictionary, it was stored as '0.25'
        # so we need to pass the *unscaled* time into round_key again.
        scaled_t_val = t_val  # e.g. 0.25
        unscaled_t_val = scaled_t_val / 1.0  # If you multiplied by 1000 above, then / 1000 here
        key = round_key(e_val, unscaled_t_val, digits=6)
        
        err = all_errors.get(key, None)
        if err is None:
            print("       -    ", end="")  # If no data for that pair
        else:
            print(f"  {err:8.4f}", end="")
    print()  # new line per eps
# Out:
# epsilon values:  [0.1, 0.07, 0.05, 0.02, 0.01]
# len of current indices:  300
# Average error for eps=0.1, t=0.25: 0.07849262754122416
# counted 60 instances of this
# Average error for eps=0.1, t=0.5: 0.0964966428776582
# counted 60 instances of this
# Average error for eps=0.1, t=0.75: 0.10421209537113706
# counted 60 instances of this
# Average error for eps=0.1, t=1.0: 0.1292709194123745
# counted 60 instances of this
# Average error for eps=0.07, t=0.25: 0.05969735638548931
# counted 60 instances of this
# Average error for eps=0.07, t=0.5: 0.048851628322154284
# counted 60 instances of this
# Average error for eps=0.07, t=0.75: 0.043466709367930886
# counted 60 instances of this
# Average error for eps=0.07, t=1.0: 0.06418078594530623
# counted 60 instances of this
# Average error for eps=0.05, t=0.25: 0.06398142334073782
# counted 60 instances of this
# Average error for eps=0.05, t=0.5: 0.048755608561138315
# counted 60 instances of this
# Average error for eps=0.05, t=0.75: 0.05025265378256639
# counted 60 instances of this
# Average error for eps=0.05, t=1.0: 0.07700383954991898
# counted 60 instances of this
# Average error for eps=0.02, t=0.25: 0.06745858620852233
# counted 60 instances of this
# Average error for eps=0.02, t=0.5: 0.046546494712432225
# counted 60 instances of this
# Average error for eps=0.02, t=0.75: 0.045260535863538585
# counted 60 instances of this
# Average error for eps=0.02, t=1.0: 0.05936531120290359
# counted 60 instances of this
# Average error for eps=0.01, t=0.25: 0.07060594179977973
# counted 60 instances of this
# Average error for eps=0.01, t=0.5: 0.04524073346207539
# counted 60 instances of this
# Average error for eps=0.01, t=0.75: 0.04414334576576948
# counted 60 instances of this
# Average error for eps=0.01, t=1.0: 0.052444045525044204
# counted 60 instances of this
# unique eps [0.01, 0.02, 0.05, 0.07, 0.1]
# unique times [0.25, 0.5, 0.75, 1.0]
#             t=0.25  t=0.5  t=0.75  t=1.0
# eps=0.010    0.0706    0.0452    0.0441    0.0524
# eps=0.020    0.0675    0.0465    0.0453    0.0594
# eps=0.050    0.0640    0.0488    0.0503    0.0770
# eps=0.070    0.0597    0.0489    0.0435    0.0642
# eps=0.100    0.0785    0.0965    0.1042    0.1293

# %%
# check if the predictions differ for different times -- have we learnt the time emb properly:

import torch
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

# Assume we have a trained model called "trained_model"
# Also assume we have (val_data, epsilon_values, time_points) available.
# We'll create a test dataset and loader.
test_dataset = AllenCahnDataset(val_data, epsilon_values, time_points)
test_loader  = DataLoader(test_dataset, batch_size=8, shuffle=True)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
trained_model.eval()

# Grab one batch from the test loader
batch = next(iter(test_loader))
batch = {k: v.to(device) for k, v in batch.items()}

initial = batch['initial']  # (B, x_size)
epsilon = batch['epsilon']  # (B, 1)
times   = batch['times']    # (B, n_timesteps-1)
target  = batch['target']   # (B, n_timesteps-1, x_size)

# Forward pass
pred = trained_model(initial, epsilon, times)  # (B, n_timesteps-1, x_size)

# We'll just pick a few samples to plot, say 2 or 3
samples_to_plot = min(3, initial.shape[0])  # e.g. 3 or less
x_size = initial.shape[-1]
x_grid = np.linspace(-1, 1, x_size)  # adapt to your domain if needed

for i in range(samples_to_plot):
    eps_val = epsilon[i].item()
    # Number of predicted time steps
    T = pred.shape[1]

    # We'll create a figure with T+1 columns:
    #  - col=0 will display the initial condition
    #  - col=1..T will display the model predictions at times[ i, 0..T-1 ]
    fig, axs = plt.subplots(nrows=1, ncols=T+1, figsize=(4*(T+1), 4))
    fig.suptitle(f"Sample {i}, Eps={eps_val:.3f}", fontsize=14)

    # Plot the initial condition in the first subplot
    axs[0].plot(x_grid, initial[i].detach().cpu().numpy(), label='Initial')
    axs[0].set_title(f"t=0.0")
    axs[0].set_xlabel("x")
    axs[0].set_ylabel("u(x)")

    # Plot the predictions (and ground truth) for each time step
    for t in range(T):
        t_val = times[i, t].item()
        ax = axs[t+1]

        # Ground truth
        ax.plot(x_grid, target[i, t].detach().cpu().numpy(), 'k', label='Truth')
        # Prediction
        ax.plot(x_grid, pred[i, t].detach().cpu().numpy(), 'r--', label='Pred')

        ax.set_title(f"t={t_val:.4f}")
        ax.set_xlabel("x")

        # Show legend for the last subplot or all subplots if you want
        if t == T-1:
            ax.legend()

    plt.tight_layout()
    plt.show()
# Out:
# epsilon values:  [0.1, 0.07, 0.05, 0.02, 0.01]
# len of current indices:  300

# %%
# here we generate the OOD dataset:

def generate_fourier_ic_ood(x, seed=None):
    """
    A 'Fourier-like' IC but with tweaked ranges so it differs from training/validation.
    E.g. we allow higher n_modes for more oscillations than in training.
    """
    if seed is not None:
        np.random.seed(seed)

    n_modes = np.random.randint(10, 30)   # bigger range than for train
    sin_coeff = np.random.normal(size=n_modes)
    cos_coeff = np.random.normal(size=n_modes)

    modes = np.arange(1, n_modes + 1)

    sin_part = sin_coeff[:, None] * np.sin(modes[:, None] * np.pi * x[None, :])
    cos_part = cos_coeff[:, None] * np.cos(modes[:, None] * np.pi * x[None, :])

    u0 = sin_part.sum(axis=0) + cos_part.sum(axis=0)

    min_val, max_val = u0.min(), u0.max()
    if max_val == min_val:
        return np.zeros_like(u0)

    # Normalize
    u0 = (u0 - min_val) / (max_val - min_val)  # [0, 1]
    u0 = 2.0 * u0 - 1.0                        # [-1, 1]
    return u0


def generate_gmm_ic_ood(x, seed=None):
    """
    A 'Gaussian mixture' IC with a different variance range and possibly more components.
    """
    if seed is not None:
        np.random.seed(seed)

    n_components = np.random.randint(3, 25)  # bigger range than for train
    means = np.random.uniform(-1, 1, size=n_components)

    # Larger variance range, or a more varied one than training
    variances = np.random.uniform(0.0005, 0.005, size=n_components)

    # Weights can be bigger in magnitude
    weights = np.random.uniform(-2, 2, size=n_components)

    diff_sq = (x[None, :] - means[:, None])**2
    exps = np.exp(-diff_sq / (2 * variances[:, None]))
    weighted_exps = weights[:, None] * exps
    u0 = weighted_exps.sum(axis=0)

    min_val, max_val = u0.min(), u0.max()
    if max_val == min_val:
        return np.zeros_like(u0)

    u0 = (u0 - min_val) / (max_val - min_val)  # [0, 1]
    u0 = 2.0 * u0 - 1.0                        # [-1, 1]
    return u0


def generate_piecewise_ic_ood(x, seed=None):
    """
    A 'piecewise linear' IC with more pieces and a bigger range for the random values.
    """
    if seed is not None:
        np.random.seed(seed)

    n_pieces = np.random.randint(5, 40)  # bigger range than for train
    breakpoints = np.random.uniform(-1, 1, size=n_pieces)
    breakpoints[0]  = -1.0
    breakpoints[-1] =  1.0
    breakpoints = np.sort(breakpoints)

    # Larger amplitude for piecewise values
    values = np.random.uniform(-2, 2, size=n_pieces)
    values[-1] = values[0]  # periodic

    slopes = (values[1:] - values[:-1]) / (breakpoints[1:] - breakpoints[:-1])

    # Wrap x into [-1, 1)
    x_wrapped = (x + 1.0) % 2.0 - 1.0
    mask_exact_one = (x_wrapped == 1.0)
    x_wrapped[mask_exact_one] = 1.0 - 1e-14

    idx = np.searchsorted(breakpoints, x_wrapped, side='right') - 1
    idx_clipped = np.clip(idx, 0, n_pieces - 2)

    u0 = values[idx_clipped] + slopes[idx_clipped] * (x_wrapped - breakpoints[idx_clipped])
    return u0


def generate_ood_dataset(n_samples, epsilon, x_grid, t_eval, ic_type='fourier', seed=None):
    """Generate dataset for Allen-Cahn equation."""
    if seed is not None:
        np.random.seed(seed)

    # Initialize dataset array
    dataset = np.zeros((n_samples, len(t_eval), len(x_grid)))

    # Generate samples
    for i in range(n_samples):
        # Generate initial condition based on type
        if ic_type == 'fourier':
            u0 = generate_fourier_ic_ood(x_grid, seed=seed+i if seed else None)
        elif ic_type == 'gmm':
            u0 = generate_gmm_ic_ood(x_grid, seed=seed+i if seed else None)
        elif ic_type == 'piecewise':
            u0 = generate_piecewise_ic_ood(x_grid, seed=seed+i if seed else None)
        else:
            raise ValueError(f"Unknown IC type: {ic_type}")

        # Solve PDE using solve_ivp
        sol = solve_ivp(
            allen_cahn_rhs,
            t_span=(t_eval[0], t_eval[-1]),
            y0=u0,
            t_eval=t_eval,
            args=(epsilon, x_grid),
            method='RK45',
            rtol=1e-6,
            atol=1e-6
        )

        dataset[i] = sol.y.T

    return dataset

def generate_ood_file():
    """Generate the ood dataset. contains rougher initial conditions and
        epilon parameters unseen in training, causing sharp transitions.

    """

    ood_data = []

    # Generate training datasets. want to end up with a mapping from eps to [n_samples * |ic_types|, |t_eval|, x_grid]
    for epsilon in ood_epsilons:
        ood_data_eps = []
        for ic_type in ic_types:
            ood_data_eps.append(generate_ood_dataset(n_ood, epsilon, x_grid, t_eval, ic_type, seed=base_seed))
        ood_data.append(np.concatenate(ood_data_eps, axis=0))

    # Save datasets as numpy files
    ood_data = np.array(ood_data)

    # Save datasets as numpy files
    np.save('ood_data.npy', ood_data, allow_pickle=True)
    print("ood data shape: ", ood_data.shape)

    return

ood_epsilons = [0.019, 0.023, 0.03, 0.055]
n_ood = n_test
generate_ood_file()
ood_data = np.load('ood_data.npy', allow_pickle=True)

# %%
def plot_three_samples(data, eps_values):
    """
      data: np.ndarray of shape (num_epsilons, num_samples, num_timesteps, num_points); train_data or val_data
      eps_values: list of epsilon values; epsilon_values or val_epsilons
    """
    # Evaluate the trained model, compare to the ground truth on three samples
    trained_model.eval()

    batch_size_for_plotting = 5

    # Create a test dataset/loader (works for train/val/ood)
    print_dataset = AllenCahnDataset(data, eps_values, time_points)
    print_loader = DataLoader(print_dataset, batch_size= batch_size_for_plotting, shuffle=True)


    # Grab one batch of size 'batch_size_for_plotting'
    batch = next(iter(print_loader))
    batch = {k: v.to(device) for k, v in batch.items()}

    initial = batch['initial']  # shape: (B, x_size)
    epsilon = batch['epsilon']  # shape: (B, 1)
    times   = batch['times']    # shape: (B, n_timesteps - 1)
    target  = batch['target']   # shape: (B, n_timesteps - 1, x_size)

    # Forward pass: pred shape = (B, n_timesteps - 1, x_size)
    pred = trained_model(initial, epsilon, times)

    # Randomly choose 3 indices to plot
    ind_for_plot = np.random.choice(pred.shape[0], 3, replace=False)
    # print("ind_for_plot:", ind_for_plot)

    # Create a 3×(1 + pred.shape[1]) = 3×5 figure
    fig, axs = plt.subplots(nrows=3, ncols=1 + pred.shape[1], figsize=(15, 9))

    for row, i in enumerate(ind_for_plot):
        # row is 0,1,2 for  chosen samples
        eps_val = epsilon[i].item()  # for labeling
        for col in range(1 + pred.shape[1]):
            ax = axs[row, col]

            if col == 0:
                # Plot the initial condition
                ax.plot(x_grid, initial[i].detach().cpu().numpy(), label='Initial')
                ax.set_title(f"Sample {i}\nEps={eps_val:.3f}, t=0.0")
                ax.set_ylabel("u(x)")
                ax.legend()
            else:
                t_val = times[i, col-1].item()

                # Plot ground truth
                ax.plot(x_grid, target[i, col-1].detach().cpu().numpy(), label='Truth')
                # Plot prediction
                ax.plot(x_grid, pred[i, col-1].detach().cpu().numpy(), '--', label='Pred')
                ax.set_title(f"Eps={eps_val:.3f}, t={t_val:.3f}")

                # Only put a legend in the last column
                if col == pred.shape[1]:
                    ax.legend()

    plt.tight_layout()
    plt.show()

print("for training data")
plot_three_samples(train_data, epsilon_values)
print("for val data")
plot_three_samples(val_data, val_epsilons)
print("for ood data")
plot_three_samples(ood_data, ood_epsilons)

# %%
def print_performance(data, eps):
    # Evaluate on the entire val / ood dataset
    perf_dataset = AllenCahnDataset(data, eps, time_points)
    perf_loader = DataLoader(perf_dataset, batch_size=32, shuffle=False)

    trained_model.eval()

    # Helper: Round (eps, time) to avoid floating-point mismatch
    def round_key(e, t, digits=6):
        """Rounds eps and time to 'digits' decimals to avoid mismatch in dictionary keys."""
        return (round(float(e), digits), round(float(t), digits))

    # dictionaries to accumulate sums of errors and counts
    all_errors = {}
    all_counts = {}

    def rel_error(pred, tgt):
        """Compute relative L2 error"""
        return torch.norm(pred - tgt) / torch.norm(tgt)

    with torch.no_grad():
        for batch in perf_loader:
            # Move batch to device
            batch = {k: v.to(device) for k, v in batch.items()}

            # Extract inputs and forward pass
            initial = batch['initial']  # (B, x_size)
            eps     = batch['epsilon']  # (B, 1)
            times   = batch['times']    # (B, n_timesteps-1)
            target  = batch['target']   # (B, n_timesteps-1, x_size)
            pred    = trained_model(initial, eps, times)  # (B, n_timesteps-1, x_size)

            B, T, X = pred.shape  # B=Batch size, T=#time points, X=#spatial points

            # Accumulate errors for each (eps_val, t_val)
            for i in range(B):
                eps_val = eps[i].item()
                for t in range(T):
                    t_val = times[i, t].item()
                    error_val = rel_error(pred[i, t], target[i, t]).item()

                    # Round (eps_val, t_val) to avoid small floating mismatches
                    key = round_key(eps_val, t_val, digits=6)

                    if key not in all_errors:
                        all_errors[key] = 0.0
                        all_counts[key] = 0

                    all_errors[key] += error_val
                    all_counts[key] += 1

    # Compute the average errors for available keys
    for key in all_errors:
        all_errors[key] /= all_counts[key]
        # print(f"Average error for eps={key[0]}, t={key[1]}: {all_errors[key]}")
        # print(f"counted { all_counts[key] } instances of this")

     #  Print out as a table: rows = eps, columns = time
    unique_eps = sorted(perf_dataset.epsilon_values)

    # Suppose test_dataset.time_points is [0, 0.00025, 0.0005, 0.00075, 0.001]
    # We skip the first entry (0.0) and rescale by TIME_SCALE => [0.25, 0.5, 0.75, 1.0]
    raw_times = perf_dataset.time_points[1:]  # e.g. [0.00025, 0.0005, 0.00075, 0.001]
    unique_times = [round(t * TIME_SCALE, 6) for t in raw_times]  # => [0.25, 0.5, 0.75, 1.0]

    print("unique eps", unique_eps)
    print("unique times", unique_times)

    # Header row
    print(" " * 10, end="")
    for t_val in unique_times:
        print(f"  t={t_val}", end="")
    print()

    # For each eps row
    for e_val in unique_eps:
        print(f"eps={e_val:5.3f}", end="")
        for t_val in unique_times:
            # We must use the same rounding we used during accumulation of errors:
            # i.e. if times were 0.25 in the dictionary, it was stored as '0.25'
            # so we need to pass the *unscaled* time into round_key again.
            scaled_t_val = t_val  # e.g. 0.25
            unscaled_t_val = scaled_t_val / 1.0  # If you multiplied by 1000 above, then / 1000 here
            key = round_key(e_val, unscaled_t_val, digits=6)

            err = all_errors.get(key, None)
            if err is None:
                print("       -    ", end="")  # If no data for that pair
            else:
                print(f"  {err:8.4f}", end="")
        print()  # new line per eps
print("the training happened on ", epsilons)
print("validation happened on a broader distribution: ")
print_performance(val_data, val_epsilons)
print("\n\n")
print("the ood epsilons are different, and the starting conditions are more complicated -- larger du/dx")
print_performance(ood_data, ood_epsilons)
